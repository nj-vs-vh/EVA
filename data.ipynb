# %% [markdown]
# # Data visualization

# %%
from matplotlib import pyplot as plt

from cr_knee_fit import experiments
from cr_knee_fit.elements import Element
from cr_knee_fit.fit_data import Data, DataConfig

# %% [markdown]
# # All available data

# %%
ALL = experiments.DIRECT + experiments.INDIRECT
conf = DataConfig(
    experiments_elements=list(ALL),
    experiments_all_particle=ALL,
    experiments_lnA=ALL,
    elements=Element.regular(),
    elements_R_bounds=(5e2, 1e8),
)

d = Data.load(conf, verbose=True)
fig, ax = plt.subplots(nrows=2, figsize=(10, 15))
fig = d.plot(scale=2.8, figure=fig)
# Out:
# Failed to load all particle spectrum data for Experiment(name='AMS-02', filename_stem='AMS-02'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/AMS-02_all_energy.txt not found.
# Failed to load all particle spectrum data for Experiment(name='CALET', filename_stem='CALET'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/CALET_all_energy.txt not found.
# Loaded all particle data for Experiment(name='DAMPE', filename_stem='DAMPE')...
# Failed to load all particle spectrum data for Experiment(name='CREAM', filename_stem='CREAM'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/CREAM_all_energy.txt not found.
# Failed to load all particle spectrum data for Experiment(name='ISS-CREAM', filename_stem='ISS-CREAM'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ISS-CREAM_all_energy.txt not found.
# Loaded all particle data for Experiment(name='HAWC (Q)', filename_stem='HAWC_QGSJET-II-04')...
# Failed to load all particle spectrum data for Experiment(name='GRAPES-3', filename_stem='GRAPES'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GRAPES_all_energy.txt not found.
# Loaded all particle data for Experiment(name='TALE (Q)', filename_stem='TALE_QGSJET-II-04')...
# Loaded all particle data for Experiment(name='GAMMA (S)', filename_stem='GAMMA_SIBYLL')...
# Loaded all particle data for Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC')...
# Loaded all particle data for Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23')...
# Loaded all particle data for Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04')...
# Loaded all particle data for Experiment(name='IceTop (S)', filename_stem='ICETOP_SIBYLL_21')...
# Loaded all particle data for Experiment(name='KASCADE (S)', filename_stem='KASCADE_SIBYLL_21')...
# Failed to load all particle spectrum data for Experiment(name='KASCADE (Q)', filename_stem='KASCADE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_QGSJET-II-04_all_energy.txt not found.
# Loaded all particle data for Experiment(name='KASCADE (2024, Q)', filename_stem='KASCADE_re_QGSJET-II-04')...
# Loaded all particle data for Experiment(name='KASCADE-Grande (S)', filename_stem='KGRANDE_SIBYLL_23')...
# Failed to load lnA for Experiment(name='AMS-02', filename_stem='AMS-02'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/AMS-02_lnA_energy.txt not found.
# Failed to load lnA for Experiment(name='CALET', filename_stem='CALET'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/CALET_lnA_energy.txt not found.
# Failed to load lnA for Experiment(name='DAMPE', filename_stem='DAMPE'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/DAMPE_lnA_energy.txt not found.
# Failed to load lnA for Experiment(name='CREAM', filename_stem='CREAM'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/CREAM_lnA_energy.txt not found.
# Failed to load lnA for Experiment(name='ISS-CREAM', filename_stem='ISS-CREAM'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ISS-CREAM_lnA_energy.txt not found.
# Failed to load lnA for Experiment(name='HAWC (Q)', filename_stem='HAWC_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/HAWC_QGSJET-II-04_lnA_energy.txt not found.
# Failed to load lnA for Experiment(name='GRAPES-3', filename_stem='GRAPES'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GRAPES_lnA_energy.txt not found.
# Failed to load lnA for Experiment(name='TALE (Q)', filename_stem='TALE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/TALE_QGSJET-II-04_lnA_energy.txt not found.
# Failed to load lnA for Experiment(name='GAMMA (S)', filename_stem='GAMMA_SIBYLL'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GAMMA_SIBYLL_lnA_energy.txt not found.
# Loaded lnA data for Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC')...
# Loaded lnA data for Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23')...
# Loaded lnA data for Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04')...
# Failed to load lnA for Experiment(name='IceTop (S)', filename_stem='ICETOP_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ICETOP_SIBYLL_21_lnA_energy.txt not found.
# Failed to load lnA for Experiment(name='KASCADE (S)', filename_stem='KASCADE_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_SIBYLL_21_lnA_energy.txt not found.
# Failed to load lnA for Experiment(name='KASCADE (Q)', filename_stem='KASCADE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_QGSJET-II-04_lnA_energy.txt not found.
# Loaded lnA data for Experiment(name='KASCADE (2024, Q)', filename_stem='KASCADE_re_QGSJET-II-04')...
# Failed to load lnA for Experiment(name='KASCADE-Grande (S)', filename_stem='KGRANDE_SIBYLL_23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KGRANDE_SIBYLL_23_lnA_energy.txt not found.
# Loaded H data for Experiment(name='AMS-02', filename_stem='AMS-02')...
# Loaded He data for Experiment(name='AMS-02', filename_stem='AMS-02')...
# Loaded C data for Experiment(name='AMS-02', filename_stem='AMS-02')...
# Loaded O data for Experiment(name='AMS-02', filename_stem='AMS-02')...
# Loaded Mg data for Experiment(name='AMS-02', filename_stem='AMS-02')...
# Loaded Si data for Experiment(name='AMS-02', filename_stem='AMS-02')...
# Loaded Fe data for Experiment(name='AMS-02', filename_stem='AMS-02')...
# Loaded H data for Experiment(name='CALET', filename_stem='CALET')...
# Loaded He data for Experiment(name='CALET', filename_stem='CALET')...
# Loaded C data for Experiment(name='CALET', filename_stem='CALET')...
# Loaded O data for Experiment(name='CALET', filename_stem='CALET')...
# Failed to load Mg spectrum from Experiment(name='CALET', filename_stem='CALET'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/CALET_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='CALET', filename_stem='CALET'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/CALET_Si_energy.txt not found.
# Loaded Fe data for Experiment(name='CALET', filename_stem='CALET')...
# Loaded H data for Experiment(name='DAMPE', filename_stem='DAMPE')...
# Loaded He data for Experiment(name='DAMPE', filename_stem='DAMPE')...
# Loaded C data for Experiment(name='DAMPE', filename_stem='DAMPE')...
# Loaded O data for Experiment(name='DAMPE', filename_stem='DAMPE')...
# Failed to load Mg spectrum from Experiment(name='DAMPE', filename_stem='DAMPE'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/DAMPE_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='DAMPE', filename_stem='DAMPE'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/DAMPE_Si_energy.txt not found.
# Loaded Fe data for Experiment(name='DAMPE', filename_stem='DAMPE')...
# Loaded H data for Experiment(name='CREAM', filename_stem='CREAM')...
# Loaded He data for Experiment(name='CREAM', filename_stem='CREAM')...
# Loaded C data for Experiment(name='CREAM', filename_stem='CREAM')...
# Loaded O data for Experiment(name='CREAM', filename_stem='CREAM')...
# Loaded Mg data for Experiment(name='CREAM', filename_stem='CREAM')...
# Loaded Si data for Experiment(name='CREAM', filename_stem='CREAM')...
# Loaded Fe data for Experiment(name='CREAM', filename_stem='CREAM')...
# Loaded H data for Experiment(name='ISS-CREAM', filename_stem='ISS-CREAM')...
# Failed to load He spectrum from Experiment(name='ISS-CREAM', filename_stem='ISS-CREAM'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ISS-CREAM_He_energy.txt not found.
# Failed to load C spectrum from Experiment(name='ISS-CREAM', filename_stem='ISS-CREAM'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ISS-CREAM_C_energy.txt not found.
# Failed to load O spectrum from Experiment(name='ISS-CREAM', filename_stem='ISS-CREAM'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ISS-CREAM_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='ISS-CREAM', filename_stem='ISS-CREAM'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ISS-CREAM_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='ISS-CREAM', filename_stem='ISS-CREAM'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ISS-CREAM_Si_energy.txt not found.
# Failed to load Fe spectrum from Experiment(name='ISS-CREAM', filename_stem='ISS-CREAM'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ISS-CREAM_Fe_energy.txt not found.
# Failed to load H spectrum from Experiment(name='HAWC (Q)', filename_stem='HAWC_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/HAWC_QGSJET-II-04_H_energy.txt not found.
# Failed to load He spectrum from Experiment(name='HAWC (Q)', filename_stem='HAWC_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/HAWC_QGSJET-II-04_He_energy.txt not found.
# Failed to load C spectrum from Experiment(name='HAWC (Q)', filename_stem='HAWC_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/HAWC_QGSJET-II-04_C_energy.txt not found.
# Failed to load O spectrum from Experiment(name='HAWC (Q)', filename_stem='HAWC_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/HAWC_QGSJET-II-04_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='HAWC (Q)', filename_stem='HAWC_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/HAWC_QGSJET-II-04_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='HAWC (Q)', filename_stem='HAWC_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/HAWC_QGSJET-II-04_Si_energy.txt not found.
# Failed to load Fe spectrum from Experiment(name='HAWC (Q)', filename_stem='HAWC_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/HAWC_QGSJET-II-04_Fe_energy.txt not found.
# Loaded H data for Experiment(name='GRAPES-3', filename_stem='GRAPES')...
# Failed to load He spectrum from Experiment(name='GRAPES-3', filename_stem='GRAPES'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GRAPES_He_energy.txt not found.
# Failed to load C spectrum from Experiment(name='GRAPES-3', filename_stem='GRAPES'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GRAPES_C_energy.txt not found.
# Failed to load O spectrum from Experiment(name='GRAPES-3', filename_stem='GRAPES'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GRAPES_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='GRAPES-3', filename_stem='GRAPES'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GRAPES_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='GRAPES-3', filename_stem='GRAPES'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GRAPES_Si_energy.txt not found.
# Failed to load Fe spectrum from Experiment(name='GRAPES-3', filename_stem='GRAPES'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GRAPES_Fe_energy.txt not found.
# Failed to load H spectrum from Experiment(name='TALE (Q)', filename_stem='TALE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/TALE_QGSJET-II-04_H_energy.txt not found.
# Failed to load He spectrum from Experiment(name='TALE (Q)', filename_stem='TALE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/TALE_QGSJET-II-04_He_energy.txt not found.
# Failed to load C spectrum from Experiment(name='TALE (Q)', filename_stem='TALE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/TALE_QGSJET-II-04_C_energy.txt not found.
# Failed to load O spectrum from Experiment(name='TALE (Q)', filename_stem='TALE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/TALE_QGSJET-II-04_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='TALE (Q)', filename_stem='TALE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/TALE_QGSJET-II-04_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='TALE (Q)', filename_stem='TALE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/TALE_QGSJET-II-04_Si_energy.txt not found.
# Failed to load Fe spectrum from Experiment(name='TALE (Q)', filename_stem='TALE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/TALE_QGSJET-II-04_Fe_energy.txt not found.
# Failed to load H spectrum from Experiment(name='GAMMA (S)', filename_stem='GAMMA_SIBYLL'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GAMMA_SIBYLL_H_energy.txt not found.
# Failed to load He spectrum from Experiment(name='GAMMA (S)', filename_stem='GAMMA_SIBYLL'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GAMMA_SIBYLL_He_energy.txt not found.
# Failed to load C spectrum from Experiment(name='GAMMA (S)', filename_stem='GAMMA_SIBYLL'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GAMMA_SIBYLL_C_energy.txt not found.
# Failed to load O spectrum from Experiment(name='GAMMA (S)', filename_stem='GAMMA_SIBYLL'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GAMMA_SIBYLL_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='GAMMA (S)', filename_stem='GAMMA_SIBYLL'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GAMMA_SIBYLL_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='GAMMA (S)', filename_stem='GAMMA_SIBYLL'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GAMMA_SIBYLL_Si_energy.txt not found.
# Failed to load Fe spectrum from Experiment(name='GAMMA (S)', filename_stem='GAMMA_SIBYLL'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/GAMMA_SIBYLL_Fe_energy.txt not found.
# Loaded H data for Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC')...
# Loaded He data for Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC')...
# Failed to load C spectrum from Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_EPOS-LHC_C_energy.txt not found.
# Failed to load O spectrum from Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_EPOS-LHC_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_EPOS-LHC_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_EPOS-LHC_Si_energy.txt not found.
# Failed to load Fe spectrum from Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_EPOS-LHC_Fe_energy.txt not found.
# Loaded H data for Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23')...
# Loaded He data for Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23')...
# Failed to load C spectrum from Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_SIBYLL-23_C_energy.txt not found.
# Failed to load O spectrum from Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_SIBYLL-23_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_SIBYLL-23_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_SIBYLL-23_Si_energy.txt not found.
# Failed to load Fe spectrum from Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_SIBYLL-23_Fe_energy.txt not found.
# Loaded H data for Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04')...
# Loaded He data for Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04')...
# Failed to load C spectrum from Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_QGSJET-II-04_C_energy.txt not found.
# Failed to load O spectrum from Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_QGSJET-II-04_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_QGSJET-II-04_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_QGSJET-II-04_Si_energy.txt not found.
# Failed to load Fe spectrum from Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_QGSJET-II-04_Fe_energy.txt not found.
# Failed to load H spectrum from Experiment(name='IceTop (S)', filename_stem='ICETOP_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ICETOP_SIBYLL_21_H_energy.txt not found.
# Failed to load He spectrum from Experiment(name='IceTop (S)', filename_stem='ICETOP_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ICETOP_SIBYLL_21_He_energy.txt not found.
# Failed to load C spectrum from Experiment(name='IceTop (S)', filename_stem='ICETOP_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ICETOP_SIBYLL_21_C_energy.txt not found.
# Failed to load O spectrum from Experiment(name='IceTop (S)', filename_stem='ICETOP_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ICETOP_SIBYLL_21_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='IceTop (S)', filename_stem='ICETOP_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ICETOP_SIBYLL_21_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='IceTop (S)', filename_stem='ICETOP_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ICETOP_SIBYLL_21_Si_energy.txt not found.
# Failed to load Fe spectrum from Experiment(name='IceTop (S)', filename_stem='ICETOP_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/ICETOP_SIBYLL_21_Fe_energy.txt not found.
# Failed to load H spectrum from Experiment(name='KASCADE (S)', filename_stem='KASCADE_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_SIBYLL_21_H_energy.txt not found.
# Failed to load He spectrum from Experiment(name='KASCADE (S)', filename_stem='KASCADE_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_SIBYLL_21_He_energy.txt not found.
# Failed to load C spectrum from Experiment(name='KASCADE (S)', filename_stem='KASCADE_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_SIBYLL_21_C_energy.txt not found.
# Failed to load O spectrum from Experiment(name='KASCADE (S)', filename_stem='KASCADE_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_SIBYLL_21_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='KASCADE (S)', filename_stem='KASCADE_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_SIBYLL_21_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='KASCADE (S)', filename_stem='KASCADE_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_SIBYLL_21_Si_energy.txt not found.
# Failed to load Fe spectrum from Experiment(name='KASCADE (S)', filename_stem='KASCADE_SIBYLL_21'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_SIBYLL_21_Fe_energy.txt not found.
# Failed to load H spectrum from Experiment(name='KASCADE (Q)', filename_stem='KASCADE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_QGSJET-II-04_H_energy.txt not found.
# Failed to load He spectrum from Experiment(name='KASCADE (Q)', filename_stem='KASCADE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_QGSJET-II-04_He_energy.txt not found.
# Failed to load C spectrum from Experiment(name='KASCADE (Q)', filename_stem='KASCADE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_QGSJET-II-04_C_energy.txt not found.
# Failed to load O spectrum from Experiment(name='KASCADE (Q)', filename_stem='KASCADE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_QGSJET-II-04_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='KASCADE (Q)', filename_stem='KASCADE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_QGSJET-II-04_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='KASCADE (Q)', filename_stem='KASCADE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_QGSJET-II-04_Si_energy.txt not found.
# Failed to load Fe spectrum from Experiment(name='KASCADE (Q)', filename_stem='KASCADE_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_QGSJET-II-04_Fe_energy.txt not found.
# Loaded H data for Experiment(name='KASCADE (2024, Q)', filename_stem='KASCADE_re_QGSJET-II-04')...
# Loaded He data for Experiment(name='KASCADE (2024, Q)', filename_stem='KASCADE_re_QGSJET-II-04')...
# Loaded C data for Experiment(name='KASCADE (2024, Q)', filename_stem='KASCADE_re_QGSJET-II-04')...
# Failed to load O spectrum from Experiment(name='KASCADE (2024, Q)', filename_stem='KASCADE_re_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_re_QGSJET-II-04_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='KASCADE (2024, Q)', filename_stem='KASCADE_re_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KASCADE_re_QGSJET-II-04_Mg_energy.txt not found.
# Loaded Si data for Experiment(name='KASCADE (2024, Q)', filename_stem='KASCADE_re_QGSJET-II-04')...
# Loaded Fe data for Experiment(name='KASCADE (2024, Q)', filename_stem='KASCADE_re_QGSJET-II-04')...
# Failed to load H spectrum from Experiment(name='KASCADE-Grande (S)', filename_stem='KGRANDE_SIBYLL_23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KGRANDE_SIBYLL_23_H_energy.txt not found.
# Failed to load He spectrum from Experiment(name='KASCADE-Grande (S)', filename_stem='KGRANDE_SIBYLL_23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KGRANDE_SIBYLL_23_He_energy.txt not found.
# Failed to load C spectrum from Experiment(name='KASCADE-Grande (S)', filename_stem='KGRANDE_SIBYLL_23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KGRANDE_SIBYLL_23_C_energy.txt not found.
# Failed to load O spectrum from Experiment(name='KASCADE-Grande (S)', filename_stem='KGRANDE_SIBYLL_23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KGRANDE_SIBYLL_23_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='KASCADE-Grande (S)', filename_stem='KGRANDE_SIBYLL_23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KGRANDE_SIBYLL_23_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='KASCADE-Grande (S)', filename_stem='KGRANDE_SIBYLL_23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KGRANDE_SIBYLL_23_Si_energy.txt not found.
# Failed to load Fe spectrum from Experiment(name='KASCADE-Grande (S)', filename_stem='KGRANDE_SIBYLL_23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/KGRANDE_SIBYLL_23_Fe_energy.txt not found.

# %% [markdown]
# # Latest data from DAMPE and LHAASO

# %%
conf = DataConfig(experiments_elements=[experiments.dampe], elements=[Element.O, Element.Fe])

d = Data.load(conf, verbose=True)
fig = d.plot(scale=2.8)
# Out:
# Loaded O data for Experiment(name='DAMPE', filename_stem='DAMPE')...
# Loaded Fe data for Experiment(name='DAMPE', filename_stem='DAMPE')...

# %%
conf = DataConfig(
    experiments_elements=[
        experiments.lhaaso_epos,
        experiments.lhaaso_qgsjet,
        experiments.lhaaso_sibyll,
    ]
)

d = Data.load(conf, verbose=True)
fig = d.plot(scale=2.8)
# Out:
# Loaded H data for Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC')...
# Loaded He data for Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC')...
# Failed to load C spectrum from Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_EPOS-LHC_C_energy.txt not found.
# Failed to load O spectrum from Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_EPOS-LHC_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_EPOS-LHC_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_EPOS-LHC_Si_energy.txt not found.
# Failed to load Fe spectrum from Experiment(name='LHAASO (E)', filename_stem='LHAASO_EPOS-LHC'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_EPOS-LHC_Fe_energy.txt not found.
# Loaded H data for Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04')...
# Loaded He data for Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04')...
# Failed to load C spectrum from Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_QGSJET-II-04_C_energy.txt not found.
# Failed to load O spectrum from Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_QGSJET-II-04_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_QGSJET-II-04_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_QGSJET-II-04_Si_energy.txt not found.
# Failed to load Fe spectrum from Experiment(name='LHAASO (Q)', filename_stem='LHAASO_QGSJET-II-04'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_QGSJET-II-04_Fe_energy.txt not found.
# Loaded H data for Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23')...
# Loaded He data for Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23')...
# Failed to load C spectrum from Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_SIBYLL-23_C_energy.txt not found.
# Failed to load O spectrum from Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_SIBYLL-23_O_energy.txt not found.
# Failed to load Mg spectrum from Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_SIBYLL-23_Mg_energy.txt not found.
# Failed to load Si spectrum from Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_SIBYLL-23_Si_energy.txt not found.
# Failed to load Fe spectrum from Experiment(name='LHAASO (S)', filename_stem='LHAASO_SIBYLL-23'): /Users/njvh/Documents/Science/GSSI/HEAPTH/galactic-cr-fit/data/output/LHAASO_SIBYLL-23_Fe_energy.txt not found.
